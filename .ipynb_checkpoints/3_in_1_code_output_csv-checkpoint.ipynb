# %% [markdown]
# # color test, assymetry test, and blue-white veil test in one code

# %% [markdown]
# ## input:
# ### -CSV file with names of the image ID's (like "PAT_123_456_789")
# ### -images with corresponding masks in the same file/ or write path below in the code
#
# ## output:
# ### -single CSV file with scores for all three features

# %%
from PIL import Image
import cv2
import numpy as np
import csv
import os



def calculate_color_score(image_path, mask_path):
    # Load the image and its corresponding mask
    image = Image.open(image_path)
    mask = Image.open(mask_path).convert('L')

    # Convert PIL image to numpy array
    rgb_img = np.array(image)
    mask = np.array(mask)

    # Find coordinates of the lesion in the mask
    lesion_coords = np.where(mask != 0)
    min_x = min(lesion_coords[0])
    max_x = max(lesion_coords[0])
    min_y = min(lesion_coords[1])
    max_y = max(lesion_coords[1])
    cropped_lesion = rgb_img[min_x:max_x, min_y:max_y]

    # Calculate the variance of colors within the lesion
    color_variance = np.var(cropped_lesion, axis=(0, 1))

    # Compute the colorfulness score as the sum of variances across all channels
    colorfulness_score = np.sum(color_variance)

    # Categorize the colorfulness score
    if colorfulness_score > 10000:
        color_score = 4
    elif colorfulness_score > 5000:
        color_score = 3
    elif colorfulness_score > 1000:
        color_score = 2
    else:
        color_score = 1

    return color_score


def calculate_symmetry_score(mask_image):
    def double_black_background(input_image):
        # Convert the input image to grayscale if it's not already
        if len(input_image.shape) > 2:
            input_image = cv2.cvtColor(input_image, cv2.COLOR_BGR2GRAY)

        # Get the size of the original image
        height, width = input_image.shape[:2]

        # Create a new image with double black background
        new_img = np.zeros((height * 2, width * 2), dtype=np.uint8)

        # Paste the original image in the center of the new image
        offset_x = (width // 2)
        offset_y = (height // 2)
        new_img[offset_y:offset_y+height, offset_x:offset_x+width] = input_image

        return new_img

    def find_longest_line(contour):
        # Find the endpoints of the longest line segment
        max_dist = 0
        endpoints = None
        for i in range(len(contour)):
            for j in range(i + 1, len(contour)):
                dist = np.linalg.norm(contour[i][0] - contour[j][0])
                if dist > max_dist:
                    max_dist = dist
                    endpoints = (contour[i][0], contour[j][0])
        return endpoints

    def rotate_image(image, angle):
        # Get the dimensions of the image
        h, w = image.shape[:2]

        # Calculate the rotation matrix
        rotation_matrix = cv2.getRotationMatrix2D((w/2, h/2), angle, 1)

        # Perform the rotation
        rotated_image = cv2.warpAffine(image, rotation_matrix, (w, h))

        return rotated_image

    def crop_to_sides(mask_image, longest_diameter):
        # Determine the angle of rotation to make the longest diameter vertical
        angle = np.degrees(np.arctan2(longest_diameter[1][1] - longest_diameter[0][1], longest_diameter[1][0] - longest_diameter[0][0]))

        # If the angle is more than 90 degrees, subtract 180 degrees to make it negative
        if angle > 90:
            angle -= 180

        # Rotate the mask image
        rotated_mask = rotate_image(mask_image, angle)

        # Find contours of the rotated lesion
        contours, _ = cv2.findContours(rotated_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

        # Find the bounding rectangle of the rotated lesion
        x, y, w, h = cv2.boundingRect(contours[0])

        # Crop the rotated mask image to include the left and right sides of the lesion
        cropped_mask = rotated_mask[y:y+h, x:x+w]

        return cropped_mask

    def calculate_pixel_differences(mask_image):

        # Total number of pixels in the mask image
        total_pixels = mask_image.size

        # Calculate the center of the mask
        center_x = mask_image.shape[1] // 2
        center_y = mask_image.shape[0] // 2

        # Split the mask into left and right halves
        left_half = mask_image[:, :center_x]
        right_half = mask_image[:, center_x:]

        # Calculate the pixel count differences on each half vertically
        left_pixel_count_vertical = cv2.countNonZero(left_half)
        right_pixel_count_vertical = cv2.countNonZero(right_half)
        vertical_difference = abs(left_pixel_count_vertical - right_pixel_count_vertical)

        # Split the mask into top and bottom halves
        top_half = mask_image[:center_y, :]
        bottom_half = mask_image[center_y:, :]

        # Calculate the pixel count differences on each half horizontally
        top_pixel_count_horizontal = cv2.countNonZero(top_half)
        bottom_pixel_count_horizontal = cv2.countNonZero(bottom_half)
        horizontal_difference = abs(top_pixel_count_horizontal - bottom_pixel_count_horizontal)

        # Calculate the fraction of similarity vertically
        vertical_similarity = 1 - (vertical_difference / total_pixels)

        # Calculate the fraction of similarity horizontally
        horizontal_similarity = 1 - (horizontal_difference / total_pixels)

        return vertical_similarity, horizontal_similarity

    def calculate_similarity_score(vertical_similarity, horizontal_similarity):
        if vertical_similarity > 0.95 and horizontal_similarity > 0.95:
            return 4
        elif vertical_similarity > 0.91 and horizontal_similarity > 0.91:
            return 3
        elif vertical_similarity > 0.8 and horizontal_similarity > 0.8:
            return 2
        else:
            return 1

    # Main function starts here
    masked_image = double_black_background(mask_image)
    longest_diameter = find_longest_diameter(masked_image)
    cropped_mask = crop_to_sides(masked_image, longest_diameter)
    vertical_similarity, horizontal_similarity = calculate_pixel_differences(cropped_mask)
    similarity_score = calculate_similarity_score(vertical_similarity, horizontal_similarity)
    return similarity_score


def calculate_blue_white_score(image_path, mask_path):

    # Load the image and mask
    image = cv2.imread(image_path)
    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

    # Resize the mask to match the dimensions of the image
    if image.shape[:2] != mask.shape[:2]:
        print("Image and mask dimensions do not match. Resizing mask...")
        mask = cv2.resize(mask, (image.shape[1], image.shape[0]))

    # Convert image to HSV color space
    hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

    # Define broader range for blue colors in HSV
    lower_blue = np.array([100, 50, 50])  # Adjusted range for blue
    upper_blue = np.array([140, 255, 255])  # Adjusted range for blue

    # Define a range for detecting white or very light colors
    lower_white = np.array([0, 0, 200])  # Range for white
    upper_white = np.array([180, 25, 255])  # Range for white

    # Create a mask for blue and white colors
    blue_mask = cv2.inRange(hsv_image, lower_blue, upper_blue)
    white_mask = cv2.inRange(hsv_image, lower_white, upper_white)
    
    if cv2.countNonZero(blue_mask)==0:
        return 0
    else:
        # Combine the blue and white masks
        combined_color_mask = cv2.bitwise_or(blue_mask, white_mask)

        # Combine the color mask with the original lesion mask
        combined_mask = cv2.bitwise_and(mask, mask, mask=combined_color_mask)

        # Calculate area of blue-white veil
        blue_white_area = cv2.countNonZero(combined_mask)

        # Calculate area of the lesion (non-zero pixels in the mask)
        lesion_area = cv2.countNonZero(mask)

        # Calculate the ratio of blue-white veil area to lesion area
        ratio = blue_white_area / lesion_area

        if ratio > 0.1:
            return 1
        else:
            return 0
        


def process_images(csv_file, image_folder, mask_folder):
    results = []

    # Open the CSV file for reading
    with open(csv_file, 'r') as csvfile:
        reader = csv.reader(csvfile)
        next(reader)  # Skip header row

        # Iterate over rows in the CSV file
        for row in reader:
            image_filename = row[0]  # Assuming image filenames are in the first column
            image_path = os.path.join(image_folder, f"{image_filename}.png")
            mask_path = os.path.join(mask_folder, f"{image_filename}_mask.png")

            try:
                color_score = calculate_color_score(image_path, mask_path)
                mask_image = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
                symmetry_score = calculate_symmetry_score(mask_image)
                blue_white_score = calculate_blue_white_score(image_path, mask_path)

                results.append({
                    'image_path': image_filename,
                    'color_score': color_score,
                    'symmetry_score': symmetry_score,
                    'blue_white_score': blue_white_score
                })
            except FileNotFoundError:
                print(f"File not found: {image_filename}. Skipping...")

    return results




def write_results_to_csv(results, output_csv):
    fieldnames = ['image_path', 'color_score', 'symmetry_score', 'blue_white_score']

    with open(output_csv, mode='w', newline='') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        for result in results:
            writer.writerow(result)


if __name__ == "__main__":
    csv_file = 'imageID_sheet.csv'  # Provide the path to your CSV file
    output_csv = 'output_results.csv'  # Output CSV file to store results
    image_folder = 'C:/Users/cieci/OneDrive/Dokumenty/GitHub/G/images_original'  # Folder containing images
    mask_folder = 'C:/Users/cieci/OneDrive/Dokumenty/GitHub/G/masks_orginal'  # Folder containing masks

    # Process images
    results = process_images(csv_file, image_folder, mask_folder)

    # Write results to CSV
    write_results_to_csv(results, output_csv)
# Out:
# File not found: PAT_924_1757_704. Skipping...
# File not found: PAT_549_1043_36. Skipping...
# File not found: PAT_677_1349_851. Skipping...
# File not found: PAT_771_1489_345. Skipping...
# File not found: PAT_664_1263_781. Skipping...
# File not found: PAT_1641_2886_284. Skipping...
# File not found: PAT_1322_1137_201. Skipping...
# File not found: PAT_1404_1393_540. Skipping...
# File not found: PAT_253_384_607. Skipping...
# File not found: PAT_837_1582_714. Skipping...
# File not found: PAT_522_986_800. Skipping...
# File not found: PAT_53_1370_288. Skipping...
# File not found: PAT_938_1789_693. Skipping...
# File not found: PAT_854_1635_103. Skipping...
# File not found: PAT_1690_3082_117. Skipping...
# File not found: PAT_595_1142_142. Skipping...
# File not found: PAT_1993_4077_139. Skipping...
# File not found: PAT_835_1578_592. Skipping...
# File not found: PAT_492_1784_50. Skipping...
# File not found: PAT_492_4723_890. Skipping...
# File not found: PAT_528_992_124. Skipping...
# File not found: PAT_709_1331_253. Skipping...
# File not found: PAT_1392_1352_778. Skipping...
# File not found: PAT_1547_4232_115. Skipping...
# File not found: PAT_184_284_721. Skipping...
# File not found: PAT_640_1210_293. Skipping...
# File not found: PAT_1067_284_533. Skipping...
# File not found: PAT_354_1814_619. Skipping...
# File not found: PAT_1708_3153_799. Skipping...
# File not found: PAT_224_1340_142. Skipping...
# File not found: PAT_198_302_44. Skipping...
# File not found: PAT_407_810_390. Skipping...
# File not found: PAT_63_99_189. Skipping...
# File not found: PAT_138_205_296. Skipping...
# File not found: PAT_90_138_369. Skipping...
# File not found: PAT_1439_1522_211. Skipping...
# File not found: PAT_705_1326_82. Skipping...
# File not found: PAT_1805_3477_772. Skipping...
# File not found: PAT_715_4073_115. Skipping...
# File not found: PAT_1572_2495_335. Skipping...
# File not found: PAT_68_105_871. Skipping...
# File not found: PAT_1506_1735_733. Skipping...
# File not found: PAT_154_237_625. Skipping...
# File not found: PAT_1252_866_852. Skipping...
# File not found: PAT_1689_3075_38. Skipping...
# File not found: PAT_1415_1439_295. Skipping...
# File not found: PAT_63_99_736. Skipping...
# File not found: PAT_464_899_646. Skipping...
# File not found: PAT_330_695_90. Skipping...
# File not found: PAT_1707_3148_835. Skipping...
# File not found: PAT_181_832_158. Skipping...
# File not found: PAT_961_1818_992. Skipping...
# File not found: PAT_126_191_304. Skipping...
# File not found: PAT_683_1296_237. Skipping...
# File not found: PAT_108_424_944. Skipping...
# File not found: PAT_558_1072_486. Skipping...
# File not found: PAT_834_4490_317. Skipping...
# File not found: PAT_927_1759_749. Skipping...
# File not found: PAT_97_151_503. Skipping...
# File not found: PAT_876_1664_579. Skipping...
# File not found: PAT_690_1309_217. Skipping...
# File not found: PAT_122_185_957. Skipping...
# File not found: PAT_2011_4141_862. Skipping...
# File not found: PAT_463_897_440. Skipping...
# File not found: PAT_824_1561_796. Skipping...
# File not found: PAT_1586_2624_615. Skipping...
# File not found: PAT_859_1638_598. Skipping...
# File not found: PAT_535_1011_567. Skipping...
# File not found: PAT_793_1512_382. Skipping...
# File not found: PAT_153_233_45. Skipping...
# File not found: PAT_1736_3246_166. Skipping...
# File not found: PAT_338_709_306. Skipping...
# File not found: PAT_950_1804_64. Skipping...
# File not found: PAT_246_377_159. Skipping...
# File not found: PAT_796_1509_459. Skipping...
# File not found: PAT_1608_2720_196. Skipping...
# File not found: PAT_819_1541_727. Skipping...
# File not found: PAT_621_3591_171. Skipping...
# File not found: PAT_16_24_691. Skipping...
# File not found: PAT_834_1572_973. Skipping...
# File not found: PAT_72_110_647. Skipping...
# File not found: PAT_152_230_934. Skipping...
# File not found: PAT_356_4511_960. Skipping...
# File not found: PAT_1388_3513_146. Skipping...
# File not found: PAT_1406_1397_669. Skipping...
# File not found: PAT_75_114_73. Skipping...
# File not found: PAT_50_76_296. Skipping...
# File not found: PAT_600_1141_988. Skipping...
# File not found: PAT_624_1180_803. Skipping...
# File not found: PAT_691_1311_2. Skipping...
# File not found: PAT_1770_3344_274. Skipping...
# File not found: PAT_362_744_283. Skipping...
# File not found: PAT_198_853_778. Skipping...
# File not found: PAT_649_1233_229. Skipping...
# File not found: PAT_386_1554_362. Skipping...
# File not found: PAT_641_1211_321. Skipping...
# File not found: PAT_966_1826_587. Skipping...
# File not found: PAT_1521_1778_763. Skipping...
# File not found: PAT_1618_2771_628. Skipping...
# File not found: PAT_601_1147_943. Skipping...
# File not found: PAT_994_1866_913. Skipping...
# File not found: PAT_557_1058_309. Skipping...
# File not found: PAT_67_104_730. Skipping...
# File not found: PAT_403_804_994. Skipping...
# File not found: PAT_465_901_106. Skipping...
# File not found: PAT_526_3205_611. Skipping...
# File not found: PAT_1414_1431_754. Skipping...
# File not found: PAT_1130_501_181. Skipping...
# File not found: PAT_841_1603_667. Skipping...
# File not found: PAT_1022_115_132. Skipping...
# File not found: PAT_1020_111_593. Skipping...
# File not found: PAT_1709_3159_144. Skipping...
# File not found: PAT_1735_3242_27. Skipping...
# File not found: PAT_926_1758_714. Skipping...
# File not found: PAT_154_235_162. Skipping...
# File not found: PAT_831_1570_637. Skipping...
# File not found: PAT_1249_862_658. Skipping...
# File not found: PAT_759_1433_914. Skipping...
# File not found: PAT_1531_1800_683. Skipping...
# File not found: PAT_2144_4738_120. Skipping...
# File not found: PAT_1370_1274_515. Skipping...
# File not found: PAT_862_1643_386. Skipping...
# File not found: PAT_2103_4581_72. Skipping...
# File not found: PAT_1365_1253_912. Skipping...
# File not found: PAT_340_714_314. Skipping...
# File not found: PAT_717_1347_899. Skipping...
# File not found: PAT_719_1361_234. Skipping...
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[19], line 269
#     266 results = process_images(csv_file, image_folder, mask_folder)
#     268 # Write results to CSV
# --> 269 write_results_to_csv(results, output_csv)
#
# Cell In[19], line 252, in write_results_to_csv(results, output_csv)
#     249 def write_results_to_csv(results, output_csv):
#     250     fieldnames = ['image_path', 'color_score', 'symmetry_score', 'blue_white_score']
# --> 252     with open(output_csv, mode='w', newline='') as csvfile:
#     253         writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
#     254         writer.writeheader()
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# PermissionError: [Errno 13] Permission denied: 'output_results.csv'
