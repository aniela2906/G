# %% [markdown]
# # Color, assymetry, and blue-white veil test in one code

# %% [markdown]
# ## INPUT:
# ### -CSV file with names of the image ID's (like "PAT_123_456_789")
# ### -images with corresponding masks in seperate folders
#
# ### image and mask should look like:
#
#  image: PAT_123_456_789.png,
#  and corresponding mask: PAT_123_456_789_mask.png
#
# ## OUTPUT:
# ### -single CSV file with scores for all three features.
#
# there is the same code at the bottom that don't need the input csv file :)
# _____________________________________________________________

# %% [markdown]
# ## How does the Color test work:
#
# ### INPUT: image path and mask path
# ### OUTPUT: color score
#
# ### Destription:
#  1. Load image and mask using PIL
#  2. Convert image and mask to numpy arrays
#  3. Get coordinates, crop
#  4. Calculate the variance of colors within the lesion
#  5. Compute the colorfulness score as the sum of variances across all color channels.
#  6. Output

# %% [markdown]
# ## How does the Asymetry test work:
# ### INPUT: mask path
# ### OUTPUT: asymmetry score
#
# ### Destription:
#
# 1. Double the black-background so the roation won't cut the mask
# 2. Find the longest diameter
# 3. Rotate over the longest diameter
# 4. Crop the image to the minimum bounding box
# 5. Calculate pixel difference, (folding vertically, and horizontally)
# 6. Output score

# %% [markdown]
# ## How does the Blue-white veil test work:
#
# ### INPUT: image path, mask path
# ### OUTPUT: yes, no if the blue-white veil is detected
#
# ### Description:
# 1. Load images
# 2. convert image to HSV color space
# 3. create mask for blue and combine with orginal mask
# 4. return ratio of blue-white0veil part/ full size of image range [0,1]
# 5. ratio >0.1 - yes, else no
#
# ### WARNING: do not upload masks that have blue pen marks around lesion, because the result won't be reliable, or make sure that the mask is not including the pen marks

# %%
from PIL import Image
import cv2
import numpy as np
import csv
import os



def calculate_color_score(image_path, mask_path):
    # load the image and its corresponding mask
    image = Image.open(image_path)
    mask = Image.open(mask_path).convert('L')

    # convert PIL image to numpy array
    rgb_img = np.array(image)
    mask = np.array(mask)

    # find coordinates of the lesion in the mask
    lesion_coords = np.where(mask != 0)
    min_x = min(lesion_coords[0])
    max_x = max(lesion_coords[0])
    min_y = min(lesion_coords[1])
    max_y = max(lesion_coords[1])
    cropped_lesion = rgb_img[min_x:max_x, min_y:max_y]

    # calculate the variance of colors
    color_variance = np.var(cropped_lesion, axis=(0, 1))

    # colorfulness score 
    colorfulness_score = np.sum(color_variance)

    # categorize the colorfulness score
    if colorfulness_score > 10000:
        color_score = 4
    elif colorfulness_score > 5000:
        color_score = 3
    elif colorfulness_score > 1000:
        color_score = 2
    else:
        color_score = 1

    return color_score


def calculate_symmetry_score(mask_image):
    def double_black_background(input_image):
        # convert the input image to grayscale (if it's not already)
        if len(input_image.shape) > 2:
            input_image = cv2.cvtColor(input_image, cv2.COLOR_BGR2GRAY)

        # get the size of the original image
        height, width = input_image.shape[:2]

        # create a new image with double black background (so while rotating we won't cut the lesion)
        new_img = np.zeros((height * 2, width * 2), dtype=np.uint8)

        # put the original image in the center of the new image
        offset_x = (width // 2)
        offset_y = (height // 2)
        new_img[offset_y:offset_y+height, offset_x:offset_x+width] = input_image

        return new_img

    def find_longest_diameter(mask_image):
        # find the longest diameter of the lesion in the mask, for rotation 
        contours, _ = cv2.findContours(mask_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        contour = max(contours, key=cv2.contourArea)
        rect = cv2.minAreaRect(contour)
        return rect



    def rotate_image(image, angle):
        # get the dimensions of the image
        h, w = image.shape[:2]

        # calculate the rotation matrix
        rotation_matrix = cv2.getRotationMatrix2D((w/2, h/2), angle, 1)

        # perform the rotation
        rotated_image = cv2.warpAffine(image, rotation_matrix, (w, h))

        return rotated_image

    def crop_to_sides(mask_image, rect):
        # determine the angle of rotation to make the longest diameter vertical
        angle = rect[2]
        if angle > 90:
            angle -= 180

        # Rotate the mask image
        rotated_mask = rotate_image(mask_image, angle)

        # Find contours of the rotated lesion
        contours, _ = cv2.findContours(rotated_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

        # Find the bounding rectangle of the rotated lesion
        x, y, w, h = cv2.boundingRect(contours[0])

        # Crop the rotated mask image to include the left and right sides of the lesion
        cropped_mask = rotated_mask[y:y+h, x:x+w]

        return cropped_mask


    def calculate_pixel_differences(mask_image):

        # Total number of pixels in the mask image
        total_pixels = mask_image.size

        # Calculate the center of the mask
        center_x = mask_image.shape[1] // 2
        center_y = mask_image.shape[0] // 2

        # Split the mask into left and right halves
        left_half = mask_image[:, :center_x]
        right_half = mask_image[:, center_x:]

        # Calculate the pixel count differences on each half vertically
        left_pixel_count_vertical = cv2.countNonZero(left_half)
        right_pixel_count_vertical = cv2.countNonZero(right_half)
        vertical_difference = abs(left_pixel_count_vertical - right_pixel_count_vertical)

        # Split the mask into top and bottom halves
        top_half = mask_image[:center_y, :]
        bottom_half = mask_image[center_y:, :]

        # Calculate the pixel count differences on each half horizontally
        top_pixel_count_horizontal = cv2.countNonZero(top_half)
        bottom_pixel_count_horizontal = cv2.countNonZero(bottom_half)
        horizontal_difference = abs(top_pixel_count_horizontal - bottom_pixel_count_horizontal)

        # Calculate the fraction of similarity vertically
        vertical_similarity = 1 - (vertical_difference / total_pixels)

        # Calculate the fraction of similarity horizontally
        horizontal_similarity = 1 - (horizontal_difference / total_pixels)

        return vertical_similarity, horizontal_similarity

    def calculate_similarity_score(vertical_similarity, horizontal_similarity):
        if vertical_similarity > 0.95 and horizontal_similarity > 0.95:
            return 4
        elif vertical_similarity > 0.91 and horizontal_similarity > 0.91:
            return 3
        elif vertical_similarity > 0.8 and horizontal_similarity > 0.8:
            return 2
        else:
            return 1

    # Main function starts here
    masked_image = double_black_background(mask_image)
    longest_diameter = find_longest_diameter(masked_image)
    cropped_mask = crop_to_sides(masked_image, longest_diameter)
    vertical_similarity, horizontal_similarity = calculate_pixel_differences(cropped_mask)
    similarity_score = calculate_similarity_score(vertical_similarity, horizontal_similarity)
    return similarity_score


def calculate_blue_white_score(image_path, mask_path):

    # Load the image and mask
    image = cv2.imread(image_path)
    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

    # Resize the mask to match the dimensions of the image
    if image.shape[:2] != mask.shape[:2]:
        print("Image and mask dimensions do not match. Resizing mask...")
        mask = cv2.resize(mask, (image.shape[1], image.shape[0]))

    # Convert image to HSV color space
    hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

    # Define broader range for blue colors in HSV
    lower_blue = np.array([100, 50, 50])  # Adjusted range for blue
    upper_blue = np.array([140, 255, 255])  # Adjusted range for blue

    # Define a range for detecting white or very light colors
    lower_white = np.array([0, 0, 200])  # Range for white
    upper_white = np.array([180, 25, 255])  # Range for white

    # Create a mask for blue and white colors
    blue_mask = cv2.inRange(hsv_image, lower_blue, upper_blue)
    white_mask = cv2.inRange(hsv_image, lower_white, upper_white)
    
    if cv2.countNonZero(blue_mask)==0:
        return 0
    else:
        # Combine the blue and white masks
        combined_color_mask = cv2.bitwise_or(blue_mask, white_mask)

        # Combine the color mask with the original lesion mask
        combined_mask = cv2.bitwise_and(mask, mask, mask=combined_color_mask)

        # Calculate area of blue-white veil
        blue_white_area = cv2.countNonZero(combined_mask)

        # Calculate area of the lesion (non-zero pixels in the mask)
        lesion_area = cv2.countNonZero(mask)

        # Calculate the ratio of blue-white veil area to lesion area
        ratio = blue_white_area / lesion_area

        if ratio > 0.1:
            return 1
        else:
            return 0
        


def process_images(csv_file, image_folder, mask_folder):
    results = []

    # Open the CSV file for reading
    with open(csv_file, 'r') as csvfile:
        reader = csv.reader(csvfile)
        next(reader)  # Skip header row

        # Iterate over rows in the CSV file
        for row in reader:
            image_filename = row[0]  # Assuming image filenames are in the first column
            image_path = os.path.join(image_folder, f"{image_filename}.png")
            mask_path = os.path.join(mask_folder, f"{image_filename}_mask.png")

            try:
                print(f"Processing image: {image_path}, mask: {mask_path}")

                color_score = calculate_color_score(image_path, mask_path)
                mask_image = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
                symmetry_score = calculate_symmetry_score(mask_image)
                blue_white_score = calculate_blue_white_score(image_path, mask_path)

                results.append({
                    'image_path': image_filename,
                    'color_score': color_score,
                    'symmetry_score': symmetry_score,
                    'blue_white_score': blue_white_score
                })
            except FileNotFoundError:
                print(f"File not found: {image_filename}. Skipping...")

    return results




def write_results_to_csv(results, output_csv):
    fieldnames = ['image_path', 'color_score', 'symmetry_score', 'blue_white_score']

    with open(output_csv, mode='w', newline='') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        for result in results:
            writer.writerow(result)


if __name__ == "__main__":
    csv_file = 'csv file with all your image IDs'  # Provide the path to your CSV file
    output_csv = 'call your new csv with results'  # Output CSV file to store results
    image_folder = "image path folder here :)"  # Folder containing images
    mask_folder = "and path for mask folder here :P"  # Folder containing masks

    # Process images
    results = process_images(csv_file, image_folder, mask_folder)

    # Write results to CSV
    write_results_to_csv(results, output_csv)
# Out:
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_104_1754_276.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_104_1754_276_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_150_1799_644.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_150_1799_644_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_154_235_30.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_154_235_30_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_164_255_119.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_164_255_119_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_173_268_1000.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_173_268_1000_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_192_296_824.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_192_296_824_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_207_313_1.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_207_313_1_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_2092_4537_438.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_2092_4537_438_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_217_1290_283.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_217_1290_283_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_237_362_52.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_237_362_52_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_245_376_24.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_245_376_24_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_252_383_31.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_252_383_31_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_260_1289_396.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_260_1289_396_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_265_407_421.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_265_407_421_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_268_413_643.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_268_413_643_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_269_415_103.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_269_415_103_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_270_1387_430.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_270_1387_430_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_270_417_257.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_270_417_257_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_27_38_240.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_27_38_240_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_309_663_812.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_309_663_812_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_313_669_908.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_313_669_908_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_325_689_528.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_325_689_528_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_40_56_160.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_40_56_160_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_75_113_165.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_75_113_165_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_83_126_820.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_83_126_820_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_96_150_743.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_96_150_743_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_2105_4587_204.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_2105_4587_204_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_622_1185_922.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_622_1185_922_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_651_1232_950.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_651_1232_950_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_657_1247_455.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT
mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_1246_846_899.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_1246_846_899_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_1288_1003_969.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_1288_1003_969_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_1307_1088_252.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_1307_1088_252_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_1308_1095_117.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_1308_1095_117_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_1350_1230_925.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_1350_1230_925_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_1364_1246_143.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_1364_1246_143_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_1367_1264_801.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_1367_1264_801_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_1370_1273_41.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_1370_1273_41_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_2150_4766_754.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_2150_4766_754_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_914_1740_932.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_914_1740_932_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_918_1742_456.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_918_1742_456_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_928_1764_426.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_928_1764_426_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_950_1804_334.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_950_1804_334_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_953_1806_845.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_953_1806_845_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_960_1816_662.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_960_1816_662_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_968_1835_721.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_968_1835_721_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_970_1833_270.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_970_1833_270_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_993_1865_559.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_993_1865_559_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/i/images\PAT_996_6_622.png, mask: C:/Users/cieci/OneDrive/Pulpit/i/masks\PAT_996_6_622_mask.png

# %% [markdown]
# ### THIS IS THE SAME CODE, BUT DON'T NEED THE .CSV WITH ALL THE IMAGE_ID'S :)

# %%
from PIL import Image
import cv2
import numpy as np
import csv
import os




def calculate_color_score(image_path, mask_path):
    # Load the image and its corresponding mask
    image = Image.open(image_path)
    mask = Image.open(mask_path).convert('L')

    # Convert PIL image to numpy array
    rgb_img = np.array(image)
    mask = np.array(mask)

    # Find coordinates of the lesion in the mask
    lesion_coords = np.where(mask != 0)
    min_x = min(lesion_coords[0])
    max_x = max(lesion_coords[0])
    min_y = min(lesion_coords[1])
    max_y = max(lesion_coords[1])
    cropped_lesion = rgb_img[min_x:max_x, min_y:max_y]

    # Calculate the variance of colors within the lesion
    color_variance = np.var(cropped_lesion, axis=(0, 1))

    # Compute the colorfulness score as the sum of variances across all channels
    colorfulness_score = np.sum(color_variance)

    # Categorize the colorfulness score
    if colorfulness_score > 10000:
        color_score = 4
    elif colorfulness_score > 5000:
        color_score = 3
    elif colorfulness_score > 1000:
        color_score = 2
    else:
        color_score = 1

    return color_score


def calculate_symmetry_score(mask_image):
    def double_black_background(input_image):
        # Convert the input image to grayscale if it's not already
        if len(input_image.shape) > 2:
            input_image = cv2.cvtColor(input_image, cv2.COLOR_BGR2GRAY)

        # Get the size of the original image
        height, width = input_image.shape[:2]

        # Create a new image with double black background
        new_img = np.zeros((height * 2, width * 2), dtype=np.uint8)

        # Paste the original image in the center of the new image
        offset_x = (width // 2)
        offset_y = (height // 2)
        new_img[offset_y:offset_y+height, offset_x:offset_x+width] = input_image

        return new_img

    def find_longest_diameter(mask_image):
        # Find the longest diameter of the lesion in the mask
        contours, _ = cv2.findContours(mask_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        contour = max(contours, key=cv2.contourArea)
        rect = cv2.minAreaRect(contour)
        return rect



    def rotate_image(image, angle):
        # Get the dimensions of the image
        h, w = image.shape[:2]

        # Calculate the rotation matrix
        rotation_matrix = cv2.getRotationMatrix2D((w/2, h/2), angle, 1)

        # Perform the rotation
        rotated_image = cv2.warpAffine(image, rotation_matrix, (w, h))

        return rotated_image

    def crop_to_sides(mask_image, rect):
        # Determine the angle of rotation to make the longest diameter vertical
        angle = rect[2]
        # If the angle is more than 90 degrees, subtract 180 degrees to make it negative
        if angle > 90:
            angle -= 180

        # Rotate the mask image
        rotated_mask = rotate_image(mask_image, angle)

        # Find contours of the rotated lesion
        contours, _ = cv2.findContours(rotated_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

        # Find the bounding rectangle of the rotated lesion
        x, y, w, h = cv2.boundingRect(contours[0])

        # Crop the rotated mask image to include the left and right sides of the lesion
        cropped_mask = rotated_mask[y:y+h, x:x+w]

        return cropped_mask


    def calculate_pixel_differences(mask_image):

        # Total number of pixels in the mask image
        total_pixels = mask_image.size

        # Calculate the center of the mask
        center_x = mask_image.shape[1] // 2
        center_y = mask_image.shape[0] // 2

        # Split the mask into left and right halves
        left_half = mask_image[:, :center_x]
        right_half = mask_image[:, center_x:]

        # Calculate the pixel count differences on each half vertically
        left_pixel_count_vertical = cv2.countNonZero(left_half)
        right_pixel_count_vertical = cv2.countNonZero(right_half)
        vertical_difference = abs(left_pixel_count_vertical - right_pixel_count_vertical)

        # Split the mask into top and bottom halves
        top_half = mask_image[:center_y, :]
        bottom_half = mask_image[center_y:, :]

        # Calculate the pixel count differences on each half horizontally
        top_pixel_count_horizontal = cv2.countNonZero(top_half)
        bottom_pixel_count_horizontal = cv2.countNonZero(bottom_half)
        horizontal_difference = abs(top_pixel_count_horizontal - bottom_pixel_count_horizontal)

        # Calculate the fraction of similarity vertically
        vertical_similarity = 1 - (vertical_difference / total_pixels)

        # Calculate the fraction of similarity horizontally
        horizontal_similarity = 1 - (horizontal_difference / total_pixels)

        return vertical_similarity, horizontal_similarity

    def calculate_similarity_score(vertical_similarity, horizontal_similarity):
        if vertical_similarity > 0.95 and horizontal_similarity > 0.95:
            return 4
        elif vertical_similarity > 0.91 and horizontal_similarity > 0.91:
            return 3
        elif vertical_similarity > 0.8 and horizontal_similarity > 0.8:
            return 2
        else:
            return 1

    # Main function starts here
    masked_image = double_black_background(mask_image)
    longest_diameter = find_longest_diameter(masked_image)
    cropped_mask = crop_to_sides(masked_image, longest_diameter)
    vertical_similarity, horizontal_similarity = calculate_pixel_differences(cropped_mask)
    similarity_score = calculate_similarity_score(vertical_similarity, horizontal_similarity)
    return similarity_score


def calculate_blue_white_score(image_path, mask_path):

    # Load the image and mask
    image = cv2.imread(image_path)
    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

    # Resize the mask to match the dimensions of the image
    if image.shape[:2] != mask.shape[:2]:
        print("Image and mask dimensions do not match. Resizing mask...")
        mask = cv2.resize(mask, (image.shape[1], image.shape[0]))

    # Convert image to HSV color space
    hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

    # Define broader range for blue colors in HSV
    lower_blue = np.array([100, 50, 50])  # Adjusted range for blue
    upper_blue = np.array([140, 255, 255])  # Adjusted range for blue

    # Define a range for detecting white or very light colors
    lower_white = np.array([0, 0, 200])  # Range for white
    upper_white = np.array([180, 25, 255])  # Range for white

    # Create a mask for blue and white colors
    blue_mask = cv2.inRange(hsv_image, lower_blue, upper_blue)
    white_mask = cv2.inRange(hsv_image, lower_white, upper_white)
    
    if cv2.countNonZero(blue_mask)==0:
        return 0
    else:
        # Combine the blue and white masks
        combined_color_mask = cv2.bitwise_or(blue_mask, white_mask)

        # Combine the color mask with the original lesion mask
        combined_mask = cv2.bitwise_and(mask, mask, mask=combined_color_mask)

        # Calculate area of blue-white veil
        blue_white_area = cv2.countNonZero(combined_mask)

        # Calculate area of the lesion (non-zero pixels in the mask)
        lesion_area = cv2.countNonZero(mask)

        # Calculate the ratio of blue-white veil area to lesion area
        ratio = blue_white_area / lesion_area

        if ratio > 0.1:
            return 1
        else:
            return 0
        


def process_images(image_folder, mask_folder, output_csv):
    results = []

    # Iterate over files in the image folder
    for image_filename in os.listdir(image_folder):
        if image_filename.endswith(".png"):  # Check if the file is a PNG image
            image_path = os.path.join(image_folder, image_filename)
            mask_filename = image_filename.split('.')[0] + '_mask.png'  # Assuming mask filenames follow this pattern
            mask_path = os.path.join(mask_folder, mask_filename)

            try:
                print(f"Processing image: {image_path}, mask: {mask_path}")

                color_score = calculate_color_score(image_path, mask_path)
                mask_image = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
                symmetry_score = calculate_symmetry_score(mask_image)
                blue_white_score = calculate_blue_white_score(image_path, mask_path)

                results.append({
                    'image_path': image_filename,
                    'color_score': color_score,
                    'symmetry_score': symmetry_score,
                    'blue_white_score': blue_white_score
                })
            except FileNotFoundError:
                print(f"File not found: {image_filename}. Skipping...")

    # Write results to CSV
    write_results_to_csv(results, output_csv)



def write_results_to_csv(results, output_csv):
    fieldnames = ['image_path', 'color_score', 'symmetry_score', 'blue_white_score']

    with open(output_csv, mode='w', newline='') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        for result in results:
            writer.writerow(result)


if __name__ == "__main__":
    image_folder = "C:/Users/cieci/OneDrive/Pulpit/s/images/images_original"  # Folder containing images
    mask_folder = "C:/Users/cieci/OneDrive/Pulpit/s/images/masks_original"  # Folder containing masks
    output_csv = 'C:/Users/cieci/OneDrive/Pulpit/s/resultsS.csv'  # Output CSV file to store results

    # Process images
    process_images(image_folder, mask_folder, output_csv)
print("done:)")
# Out:
# Processing image: C:/Users/cieci/OneDrive/Pulpit/s/images/images_original\PAT_101_1041_898.png, mask: C:/Users/cieci/OneDrive/Pulpit/s/images/masks_original\PAT_101_1041_898_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/s/images/images_original\PAT_1063_271_448.png, mask: C:/Users/cieci/OneDrive/Pulpit/s/images/masks_original\PAT_1063_271_448_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/s/images/images_original\PAT_106_158_270.png, mask: C:/Users/cieci/OneDrive/Pulpit/s/images/masks_original\PAT_106_158_270_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/s/images/images_original\PAT_1074_322_864.png, mask: C:/Users/cieci/OneDrive/Pulpit/s/images/masks_original\PAT_1074_322_864_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/s/images/images_original\PAT_1089_375_60.png, mask: C:/Users/cieci/OneDrive/Pulpit/s/images/masks_original\PAT_1089_375_60_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/s/images/images_original\PAT_1107_427_352.png, mask: C:/Users/cieci/OneDrive/Pulpit/s/images/masks_original\PAT_1107_427_352_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/s/images/images_original\PAT_113_172_610.png, mask: C:/Users/cieci/OneDrive/Pulpit/s/images/masks_original\PAT_113_172_610_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/s/images/images_original\PAT_1148_542_708.png, mask: C:/Users/cieci/OneDrive/Pulpit/s/images/masks_original\PAT_1148_542_708_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/s/images/images_original\PAT_115_1138_970.png, mask: C:/Users/cieci/OneDrive/Pulpit/s/images/masks_original\PAT_115_1138_970_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/s/images/images_original\PAT_1180_650_843.png, mask: C:/Users/cieci/OneDrive/Pulpit/s/images/masks_original\PAT_1180_650_843_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/s/images/images_original\PAT_1185_679_115.png, mask: C:/Users/cieci/OneDrive/Pulpit/s/images/masks_original\PAT_1185_679_115_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/s/images/images_original\PAT_118_180_500.png, mask: C:/Users/cieci/OneDrive/Pulpit/s/images/masks_original\PAT_118_180_500_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/s/images/images_original\PAT_1202_722_827.png, mask: C:/Users/cieci/OneDrive/Pulpit/s/images/masks_original\PAT_1202_722_827_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/s/images/images_original\PAT_1260_894_63.png, mask: C:/Users/cieci/OneDrive/Pulpit/s/images/masks_original\PAT_1260_894_63_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/s/images/images_original\PAT_1303_1077_501.png, mask: C:/Users/cieci/OneDrive/Pulpit/s/images/masks_original\PAT_1303_1077_501_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/s/images/images_original\PAT_1304_1081_84.png, mask: C:/Users/cieci/OneDrive/Pulpit/s/images/masks_original\PAT_1304_1081_84_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/s/images/images_original\PAT_1345_1223_175.png, mask: C:/Users/cieci/OneDrive/Pulpit/s/images/masks_original\PAT_1345_1223_175_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/s/images/images_original\PAT_139_207_342.png, mask: C:/Users/cieci/OneDrive/Pulpit/s/images/masks_original\PAT_139_207_342_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/s/images/images_original\PAT_1414_1433_570.png, mask: C:/Users/cieci/OneDrive/Pulpit/s/images/masks_original\PAT_1414_1433_570_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/s/images/images_original\PAT_1415_1437_743.png, mask: C:/Users/cieci/OneDrive/Pulpit/s/images/masks_original\PAT_1415_1437_743_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/s/images/images_original\PAT_1415_1440_629.png, mask: C:/Users/cieci/OneDrive/Pulpit/s/images/masks_original\PAT_1415_1440_629_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/s/images/images_original\PAT_1421_1464_297.png, mask: C:/Users/cieci/OneDrive/Pulpit/s/images/masks_original\PAT_1421_1464_297_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/s/images/images_original\PAT_1455_1585_690.png, mask: C:/Users/cieci/OneDrive/Pulpit/s/images/masks_original\PAT_1455_1585_690_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/s/images/images_original\PAT_145_216_110.png, mask: C:/Users/cieci/OneDrive/Pulpit/s/images/masks_original\PAT_145_216_110_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/s/images/images_original\PAT_148_220_174.png, mask: C:/Users/cieci/OneDrive/Pulpit/s/images/masks_original\PAT_148_220_174_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/s/images/images_original\PAT_149_221_679.png, mask: C:/Users/cieci/OneDrive/Pulpit/s/images/masks_original\PAT_149_221_679_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/s/images/images_original\PAT_1520_1777_935.png, mask: C:/Users/cieci/OneDrive/Pulpit/s/images/masks_original\PAT_1520_1777_935_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/s/images/images_original\PAT_1554_2392_767.png, mask: C:/Users/cieci/OneDrive/Pulpit/s/images/masks_original\PAT_1554_2392_767_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/s/images/images_original\PAT_1563_2425_443.png, mask: C:/Users/cieci/OneDrive/Pulpit/s/images/masks_original\PAT_1563_2425_443_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/s/images/images_original\PAT_1571_2484_488.png, mask: C:/Users/cieci/OneDrive/Pulpit/s/images/masks_original\PAT_1571_2484_488_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/s/images/images_original\PAT_1577_3527_831.png, mask: C:/Users/cieci/OneDrive/Pulpit/s/images/masks_original\PAT_1577_3527_831_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/s/images/images_original\PAT_159_245_181.png, mask: C:/Users/cieci/OneDrive/Pulpit/s/images/masks_original\PAT_159_245_181_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/s/images/images_original\PAT_1633_2855_460.png, mask: C:/Users/cieci/OneDrive/Pulpit/s/images/masks_original\PAT_1633_2855_460_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/s/images/images_original\PAT_1671_3008_622.png, mask: C:/Users/cieci/OneDrive/Pulpit/s/images/masks_original\PAT_1671_3008_622_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/s/images/images_original\PAT_167_258_479.png, mask: C:/Users/cieci/OneDrive/Pulpit/s/images/masks_original\PAT_167_258_479_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/s/images/images_original\PAT_1701_3136_33.png, mask: C:/Users/cieci/OneDrive/Pulpit/s/images/masks_original\PAT_1701_3136_33_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/s/images/images_original\PAT_172_267_557.png, mask: C:/Users/cieci/OneDrive/Pulpit/s/images/masks_original\PAT_172_267_557_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/s/images/images_original\PAT_1734_3240_299.png, mask: C:/Users/cieci/OneDrive/Pulpit/s/images/masks_original\PAT_1734_3240_299_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/s/images/images_original\PAT_1786_3419_768.png, mask: C:/Users/cieci/OneDrive/Pulpit/s/images/masks_original\PAT_1786_3419_768_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/s/images/images_original\PAT_1787_3421_516.png, mask: C:/Users/cieci/OneDrive/Pulpit/s/images/masks_original\PAT_1787_3421_516_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/s/images/images_original\PAT_1850_3631_519.png, mask: C:/Users/cieci/OneDrive/Pulpit/s/images/masks_original\PAT_1850_3631_519_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/s/images/images_original\PAT_1855_3641_327.png, mask: C:/Users/cieci/OneDrive/Pulpit/s/images/masks_original\PAT_1855_3641_327_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/s/images/images_original\PAT_1969_3980_995.png, mask: C:/Users/cieci/OneDrive/Pulpit/s/images/masks_original\PAT_1969_3980_995_mask.png
# Processing image: C:/Users/cieci/OneDrive/Pulpit/s/images/images_original\PAT